# %%
import pandas as pd

# %%
data = {
    'a':[5,8,9,6],
    'b':[1,2,4,8],
    'c':['ml','dl','aws','genAI']
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    a  b      c
# 0  5  1     ml
# 1  8  2     dl
# 2  9  4    aws
# 3  6  8  genAI

# %%
df.set_index('a',inplace=True)

# %%
df
# Out:
#    b      c
# a
# 5  1     ml
# 8  2     dl
# 9  4    aws
# 6  8  genAI

# %%
df = df.reset_index()

# %%
df
# Out:
#    a  b      c
# 0  5  1     ml
# 1  8  2     dl
# 2  9  4    aws
# 3  6  8  genAI

# %%
df['a']
# Out:
# 0    5
# 1    8
# 2    9
# 3    6
# Name: a, dtype: int64

# %%
list(df['a'])
# Out:
# [5, 8, 9, 6]

# %%
[i for i in df['a']]
# Out:
# [5, 8, 9, 6]

# %% [markdown]
# ## Apply

# %%
def test(x):
    return x.sum()
df.apply(test,axis=0)
# Out:
# a              28
# b              15
# c    mldlawsgenAI
# dtype: object

# %% [markdown]
# ## ApplyMap

# %%
df1 = df[['a','b']]

# %%
df1
# Out:
#    a  b
# 0  5  1
# 1  8  2
# 2  9  4
# 3  6  8

# %%
df1.applymap(lambda x:x**2)
# Out:
#     a   b
# 0  25   1
# 1  64   4
# 2  81  16
# 3  36  64

# %%
df
# Out:
#    a  b      c
# 0  5  1     ml
# 1  8  2     dl
# 2  9  4    aws
# 3  6  8  genAI

# %% [markdown]
# ## Sort

# %%
df.sort_values('c')
# Out:
#    a  b      c
# 2  9  4    aws
# 1  8  2     dl
# 3  6  8  genAI
# 0  5  1     ml

# %%
df.sort_index(ascending=False)
# Out:
#    a  b      c
# 3  6  8  genAI
# 2  9  4    aws
# 1  8  2     dl
# 0  5  1     ml

# %% [markdown]
# ## Set_Option

# %%
df2 = pd.DataFrame({'Desc':["DataScience is a channel dedicated to providing high-quality learning content for data science enthusiasts and practitioners. The channel covers various topics related to data science, including data analysis, data visualization, machine learning, deep learning, natural language processing, and more.Stay Motivated and Keep Learning. This repository contains day-wise notes and code snippets for our comprehensive crash course on Data Science. This comprehensive crash course is designed to provide you with a solid foundation in data science using Python. Each day covers key topics, hands-on exercises, and practical examples to help you master essential concepts in a step-by-step manner, laying the foundation for a successful journey into the world of data science and Gen AI."]})

# %%
df2
# Out:
#                                                 Desc
# 0  DataScience is a channel dedicated to providin...

# %%
pd.set_option("display.max_colwidth",1000)
df2 = pd.DataFrame({'Desc':["DataScience is a channel dedicated to providing high-quality learning content for data science enthusiasts and practitioners. The channel covers various topics related to data science, including data analysis, data visualization, machine learning, deep learning, natural language processing, and more.Stay Motivated and Keep Learning. This repository contains day-wise notes and code snippets for our comprehensive crash course on Data Science. This comprehensive crash course is designed to provide you with a solid foundation in data science using Python. Each day covers key topics, hands-on exercises, and practical examples to help you master essential concepts in a step-by-step manner, laying the foundation for a successful journey into the world of data science and Gen AI."]})

# %%
df2
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Desc
# 0  DataScience is a channel dedicated to providing high-quality learning content for data science enthusiasts and practitioners. The channel covers various topics related to data science, including data analysis, data visualization, machine learning, deep learning, natural language processing, and more.Stay Motivated and Keep Learning. This repository contains day-wise notes and code snippets for our comprehensive crash course on Data Science. This comprehensive crash course is designed to provide you with a solid foundation in data science using Python. Each day covers key topics, hands-on exercises, and practical examples to help you master essential concepts in a step-by-step manner, laying the foundation for a successful journey into the world of data science and Gen AI.

# %%
pd.set_option("display.max_colwidth",1000)

df2  = pd.DataFrame({'Desc':["DataScience is a channel dedicated to providing high-quality learning content for data science enthusiasts and practitioners. The channel covers various topics related to data science, including data analysis, data visualization, machine learning, deep learning, natural language processing, and more.Stay Motivated and Keep Learning. This repository contains day-wise notes and code snippets for our comprehensive crash course on Data Science. This comprehensive crash course is designed to provide you with a solid foundation in data science using Python. Each day covers key topics, hands-on exercises, and practical examples to help you master essential concepts in a step-by-step manner, laying the foundation for a successful journey into the world of data science and Gen AI.",'Welcome To Our youtube Channel DataScience','Data Science Master']})

# %%
df2
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Desc
# 0  DataScience is a channel dedicated to providing high-quality learning content for data science enthusiasts and practitioners. The channel covers various topics related to data science, including data analysis, data visualization, machine learning, deep learning, natural language processing, and more.Stay Motivated and Keep Learning. This repository contains day-wise notes and code snippets for our comprehensive crash course on Data Science. This comprehensive crash course is designed to provide you with a solid foundation in data science using Python. Each day covers key topics, hands-on exercises, and practical examples to help you master essential concepts in a step-by-step manner, laying the foundation for a successful journey into the world of data science and Gen AI.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Welcome To Our youtube Channel DataScience
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Data Science Master

# %%
df2['length']=df2['Desc'].apply(len)

# %%
df2
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Desc  \
# 0  DataScience is a channel dedicated to providing high-quality learning content for data science enthusiasts and practitioners. The channel covers various topics related to data science, including data analysis, data visualization, machine learning, deep learning, natural language processing, and more.Stay Motivated and Keep Learning. This repository contains day-wise notes and code snippets for our comprehensive crash course on Data Science. This comprehensive crash course is designed to provide you with a solid foundation in data science using Python. Each day covers key topics, hands-on exercises, and practical examples to help you master essential concepts in a step-by-step manner, laying the foundation for a successful journey into the world of data science and Gen AI.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Welcome To Our youtube Channel DataScience
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Data Science Master
#
#    length
# 0     782
# 1      42
# 2      19

# %%
s = "Hello All Welcome To Our Youtube Channel DataScience"
len(s.split())
# Out:
# 8

# %%
df2['words_count'] = df2['Desc'].apply(lambda x: len(x.split()))

# %%
df2
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Desc  \
# 0  DataScience is a channel dedicated to providing high-quality learning content for data science enthusiasts and practitioners. The channel covers various topics related to data science, including data analysis, data visualization, machine learning, deep learning, natural language processing, and more.Stay Motivated and Keep Learning. This repository contains day-wise notes and code snippets for our comprehensive crash course on Data Science. This comprehensive crash course is designed to provide you with a solid foundation in data science using Python. Each day covers key topics, hands-on exercises, and practical examples to help you master essential concepts in a step-by-step manner, laying the foundation for a successful journey into the world of data science and Gen AI.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Welcome To Our youtube Channel DataScience
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Data Science Master
#
#    length  words_count
# 0     782          113
# 1      42            6
# 2      19            3

# %%
df
# Out:
#    a  b      c
# 0  5  1     ml
# 1  8  2     dl
# 2  9  4    aws
# 3  6  8  genAI

# %%
df['a'][1]
# Out:
# 8

# %%
df['a'].sum()
# Out:
# 28

# %%
df['a'].mean()
# Out:
# 7.0

# %%
df['b'].median()
# Out:
# 3.0

# %%
df['b'].mode()
# Out:
# 0    1
# 1    2
# 2    4
# 3    8
# Name: b, dtype: int64

# %%
df['a'].std()
# Out:
# 1.8257418583505538

# %%
df['a'].max()
# Out:
# 9

# %%
df['b'].min()
# Out:
# 1

# %%
df['b'].var()
# Out:
# 9.583333333333334

# %% [markdown]
# ## Pandas - Windows Function

# %%
df3 = pd.DataFrame({'a':[3,4,5,2,1,3,4,5,6]})

# %%
df3
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df3['a'].rolling(window = 1).mean()
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    2.0
# 4    1.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
df3['a'].rolling(window = 2).mean()
# Out:
# 0    NaN
# 1    3.5
# 2    4.5
# 3    3.5
# 4    1.5
# 5    2.0
# 6    3.5
# 7    4.5
# 8    5.5
# Name: a, dtype: float64

# %%
df3['a'].rolling(window = 3).mean()
# Out:
# 0         NaN
# 1         NaN
# 2    4.000000
# 3    3.666667
# 4    2.666667
# 5    2.000000
# 6    2.666667
# 7    4.000000
# 8    5.000000
# Name: a, dtype: float64

# %%
df3['a'].rolling(window = 3).sum()
# Out:
# 0     NaN
# 1     NaN
# 2    12.0
# 3    11.0
# 4     8.0
# 5     6.0
# 6     8.0
# 7    12.0
# 8    15.0
# Name: a, dtype: float64

# %%
df3['a'].rolling(window = 3).min()
# Out:
# 0    NaN
# 1    NaN
# 2    3.0
# 3    2.0
# 4    1.0
# 5    1.0
# 6    1.0
# 7    3.0
# 8    4.0
# Name: a, dtype: float64

# %%
df3
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df3['a'].cumsum()  #cumulative sum
# Out:
# 0     3
# 1     7
# 2    12
# 3    14
# 4    15
# 5    18
# 6    22
# 7    27
# 8    33
# Name: a, dtype: int64

# %% [markdown]
# ## Pandas - Data Functionality

# %%
date = pd.date_range(start='2024-02-22', end='2024-04-22')

# %%
date
# Out:
# DatetimeIndex(['2024-02-22', '2024-02-23', '2024-02-24', '2024-02-25',
#                '2024-02-26', '2024-02-27', '2024-02-28', '2024-02-29',
#                '2024-03-01', '2024-03-02', '2024-03-03', '2024-03-04',
#                '2024-03-05', '2024-03-06', '2024-03-07', '2024-03-08',
#                '2024-03-09', '2024-03-10', '2024-03-11', '2024-03-12',
#                '2024-03-13', '2024-03-14', '2024-03-15', '2024-03-16',
#                '2024-03-17', '2024-03-18', '2024-03-19', '2024-03-20',
#                '2024-03-21', '2024-03-22', '2024-03-23', '2024-03-24',
#                '2024-03-25', '2024-03-26', '2024-03-27', '2024-03-28',
#                '2024-03-29', '2024-03-30', '2024-03-31', '2024-04-01',
#                '2024-04-02', '2024-04-03', '2024-04-04', '2024-04-05',
#                '2024-04-06', '2024-04-07', '2024-04-08', '2024-04-09',
#                '2024-04-10', '2024-04-11', '2024-04-12', '2024-04-13',
#                '2024-04-14', '2024-04-15', '2024-04-16', '2024-04-17',
#                '2024-04-18', '2024-04-19', '2024-04-20', '2024-04-21',
#                '2024-04-22'],
#               dtype='datetime64[ns]', freq='D')

# %%
type(date)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df_date=pd.DataFrame({'date':date})

# %%
df_date
# Out:
#          date
# 0  2024-02-22
# 1  2024-02-23
# 2  2024-02-24
# 3  2024-02-25
# 4  2024-02-26
# ..        ...
# 56 2024-04-18
# 57 2024-04-19
# 58 2024-04-20
# 59 2024-04-21
# 60 2024-04-22
#
# [61 rows x 1 columns]

# %%
df_date.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %%
df5 = pd.DataFrame({'date':['2024-04-20','2024-04-18','2024-04-22']})

# %%
df5
# Out:
#          date
# 0  2024-04-20
# 1  2024-04-18
# 2  2024-04-22

# %%
df5.dtypes
# Out:
# date    object
# dtype: object

# %%
df5['updated_dates'] =pd.to_datetime(df5['date'])

# %%
df5['year']=df5['updated_dates'].dt.year

# %%
df5
# Out:
#          date updated_dates  year
# 0  2024-04-20    2024-04-20  2024
# 1  2024-04-18    2024-04-18  2024
# 2  2024-04-22    2024-04-22  2024

# %%
df5['day']=df5['updated_dates'].dt.day

# %%
df5
# Out:
#          date updated_dates  year  day
# 0  2024-04-20    2024-04-20  2024   20
# 1  2024-04-18    2024-04-18  2024   18
# 2  2024-04-22    2024-04-22  2024   22

# %%
df5['month']=df5['updated_dates'].dt.month

# %%
df5
# Out:
#          date updated_dates  year  day  month
# 0  2024-04-20    2024-04-20  2024   20      4
# 1  2024-04-18    2024-04-18  2024   18      4
# 2  2024-04-22    2024-04-22  2024   22      4

# %%
df5.dtypes
# Out:
# date                     object
# updated_dates    datetime64[ns]
# year                      int32
# day                       int32
# month                     int32
# dtype: object

# %% [markdown]
# ## Pandas - Time Delta

# %%
pd.Timedelta(days=1,hours=7, minutes = 45)
# Out:
# Timedelta('1 days 07:45:00')

# %%
dt = pd.to_datetime('2024-02-22')

# %%
dt
# Out:
# Timestamp('2024-02-22 00:00:00')

# %%
td = pd.Timedelta(days=2)

# %%
dt+td
# Out:
# Timestamp('2024-02-24 00:00:00')

# %% [markdown]
# ## Categorical Data

# %%
data= ['ml','dl','aws','cloud','ml','python']

# %%
c= pd.Categorical(data)

# %%
c
# Out:
# ['ml', 'dl', 'aws', 'cloud', 'ml', 'python']
# Categories (5, object): ['aws', 'cloud', 'dl', 'ml', 'python']

# %%
c.value_counts()
# Out:
# aws       1
# cloud     1
# dl        1
# ml        2
# python    1
# Name: count, dtype: int64

# %% [markdown]
# ## pandas - Visualization

# %%
s = pd.Series([1,2,3,5,8,9,6,7])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    5
# 4    8
# 5    9
# 6    6
# 7    7
# dtype: int64

# %%
s.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame({
    'a':[3,4,5,6,7],
    'b':[4,5,6,7,8]
})

# %%
df
# Out:
#    a  b
# 0  3  4
# 1  4  5
# 2  5  6
# 3  6  7
# 4  7  8

# %%
df.plot(x='a',y='b')
# Out:
# <Axes: xlabel='a'>

# %%
df.plot.scatter(x='a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    5
# 4    8
# 5    9
# 6    6
# 7    7
# dtype: int64

# %%
s.plot.pie()
# Out:
# <Axes: >
